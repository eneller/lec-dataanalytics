# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# a) Erstellen des Datasets mit make_blobs

coords, categories = make_blobs(n_features=2, n_samples=300, centers=4, cluster_std=.6, random_state=1)
x_coord = [s[0] for s in coords]
y_coord = [s[1] for s in coords]

# %%
# b) Plotten des Datensets
plt.scatter(x_coord, y_coord)

# %%
# c) Anwenden der Elbow Methode
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 1)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# d) Trainieren des KMeans mit den in Teilaufgabe d) erarbeiteten k Clusterzentren
kmeans = KMeans(n_clusters = 4, init = 'k-means++',max_iter = 300, n_init = 10,  random_state = 1)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=1)

# %%
# e) Vorhersage
y_pred = kmeans.predict(X)

# %%
# f) Plotten des Datasets mit Clusterzentren
centers = kmeans.cluster_centers_
plt.scatter(x=X[:,0], y=X[:,1], s=30, c=y_pred,cmap="viridis")
plt.scatter(x=centers[:,0], y=centers[:,1], s=30, c='red')
plt.show()
